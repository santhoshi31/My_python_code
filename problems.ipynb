# %%
a = int(input("entry number"))
dummy = 0
while (a > 0):
    dummy += a % 10
    a //= 10
print(dummy)
# Out:
# entry number 5678
# 26

# %%
a = (input("entry number"))
count = 0
for char in a :
    if char in[ "a","e","i","o","u"]:
        count += 1

print(count)
# Out:
# entry number i love santa
# 5

# %%
a = int(input("entry number"))
if a == 0:
    print("Zero")
elif a > 0:
    print("Positive")
elif a < 0:
    print("Negative")
# Out:
# entry number -7
# Negative
